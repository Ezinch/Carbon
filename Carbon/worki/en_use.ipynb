# %%
import pandas as pd

# %%
en_use = pd.read_excel('energy_use.xlsx')
en_use
# Out:
#             Country       2000       2001       2002       2003       2004  \
# 0         Australia    2545.70    2554.74    2553.62    2654.80    2722.53
# 1           Austria     920.70     936.06     940.63     956.21     967.52
# 2           Belgium        NaN        NaN        NaN        NaN        NaN
# 3            Canada    6900.56    6717.35    6852.97    6936.26    7148.62
# 4    Czech Republic    1048.29    1057.30    1041.65    1087.11    1108.90
# 5           Denmark     560.18     558.21     560.45     564.43     560.83
# 6           Finland     982.35     980.93    1010.13    1023.19    1039.52
# 7            France    5865.09    5992.48    5995.41    6011.50    5966.83
# 8           Germany    8768.07    8819.01    8725.80    8782.09    8669.33
# 9            Greece     688.01     711.24     732.78     758.47     771.22
# 10          Hungary     714.42     719.91     733.15     732.80     739.88
# ...

# %%
en_use = en_use.melt(id_vars = 'Country', var_name = 'Year', value_name = 'energy_use')

# %%
en_use
# Out:
#             Country  Year  energy_use
# 0         Australia  2000     2545.70
# 1           Austria  2000      920.70
# 2           Belgium  2000         NaN
# 3            Canada  2000     6900.56
# 4    Czech Republic  2000     1048.29
# ..              ...   ...         ...
# 589  United Kingdom  2021         NaN
# 590   United States  2021         NaN
# 591             IEA  2021   122842.49
# 592          Brazil  2021         NaN
# 593        Slovenia  2021         NaN
#
# [594 rows x 3 columns]

# %%
en_use.to_csv('en_use.csv', index=False)
