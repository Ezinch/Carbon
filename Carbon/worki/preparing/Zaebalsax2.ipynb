# %%
import pandas as pd

# %%
df = pd.read_excel('data2.xlsx')

# %%
en = pd.read_excel('en_use_sectoral2.xlsx')

# %%
em = pd.read_excel('emiss2.xlsx')

# %%
df = pd.merge_ordered(df, en)

# %%
df = pd.merge_ordered(df, em)

# %%
df.dropna(inplace=True, ignore_index = True)
df
# Out:
#            Country  Year  Emission  Energy use  Energy efficiency  \
# 0        Australia  2000    274.33     2545.70              0.000
# 1        Australia  2001    281.47     2554.74             17.152
# 2        Australia  2002    285.92     2553.62              0.000
# 3        Australia  2003    289.42     2654.80             15.887
# 4        Australia  2004    300.42     2722.53             55.633
# ..             ...   ...       ...         ...                ...
# 513  United States  2016   4241.08    54460.04           1868.364
# 514  United States  2017   4196.40    54939.22           1974.924
# 515  United States  2018   4266.79    56461.94           2464.632
# 516  United States  2019   4222.79    57239.83           2549.316
# 517  United States  2020   3615.86    50234.83           2783.658
#
#      Fossil fuels  Hydrogen and fuel cells   Nuclear  \
# 0           0.000                    0.000     0.000
# 1         118.584                    0.000     5.329
# ...

# %%
df.to_excel('data3.xlsx', index=False)
