# %%
import pandas as pd

# %%
inv = pd.read_excel("invest.xlsx")

# %%
inv
# Out:
#                                             Country/Area  Year  \
# 0                                    European Union (27)  2020
# 1                                    European Union (27)  2019
# 2                                    European Union (27)  2020
# 3                                    European Union (27)  2020
# 4                                    European Union (27)  2020
# ...                                                  ...   ...
# 16519  United Kingdom of Great Britain and Northern I...  2018
# 16520  United Kingdom of Great Britain and Northern I...  2015
# 16521  United Kingdom of Great Britain and Northern I...  2015
# 16522  United Kingdom of Great Britain and Northern I...  2016
# 16523  United Kingdom of Great Britain and Northern I...  2015
#
#        Amount (2020 USD million)
# 0                       0.583190
# 1                       4.882124
# 2                       0.680388
# 3                       0.777586
# 4                       0.155517
# ...

# %%
new_inv = inv.groupby(['Country/Area', 'Year'])['Amount (2020 USD million)'].sum().reset_index()

# %%
new_inv = new_inv.rename(columns={'Country/Area':'Country'})

# %%
new_inv.to_csv('new_inv.csv',index=False)

# %%
new_inv
# Out:
#           Country  Year  Amount (2020 USD million)
# 0     Afghanistan  2000                   0.023564
# 1     Afghanistan  2001                   0.126525
# 2     Afghanistan  2002                  15.661199
# 3     Afghanistan  2003                  26.062467
# 4     Afghanistan  2004                  60.089606
# ...           ...   ...                        ...
# 2590     Zimbabwe  2016                   0.032496
# 2591     Zimbabwe  2017                   5.574095
# 2592     Zimbabwe  2018                 967.543716
# 2593     Zimbabwe  2019                   0.254309
# 2594     Zimbabwe  2020                   0.011643
#
# [2595 rows x 3 columns]

# %%
# Out:
#           Country  Year  Amount (2020 USD million)
# 0     Afghanistan  2000                   0.023564
# 1     Afghanistan  2001                   0.126525
# 2     Afghanistan  2002                  15.661199
# 3     Afghanistan  2003                  26.062467
# 4     Afghanistan  2004                  60.089606
# ...           ...   ...                        ...
# 2590     Zimbabwe  2016                   0.032496
# 2591     Zimbabwe  2017                   5.574095
# 2592     Zimbabwe  2018                 967.543716
# 2593     Zimbabwe  2019                   0.254309
# 2594     Zimbabwe  2020                   0.011643
#
# [2595 rows x 3 columns]
